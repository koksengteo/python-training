# %%
2*(3+4)
# Out:
# 14

# %% [markdown]
# My First Notebook

# %%
print('first value:',1)
print('second value:',2)
# Out:
# first value: 1
# second value: 2

# %%
Numbers=[4,3,2,1]
Numbers.sort()
print(Numbers)
# Out:
# [1, 2, 3, 4]
